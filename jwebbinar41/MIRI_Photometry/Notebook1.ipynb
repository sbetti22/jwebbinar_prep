# %% [markdown]
# # Workshop Notebook #1 - MIRI Photometry Solutions
#
# ## Author: Taylor Bell (ESA/AURA for STScI)
#
# Run the Setup.ipynb notebook to download the data. The setup notebook needs to just be run **once**.

# %% [markdown]
# # Installing Eureka! on your computer
#
# You should first follow the installation instructions at https://eurekadocs.readthedocs.io/en/latest/installation.html to install Eureka! on your computer.

# %% [markdown]
# ---
# # Setting up the notebook
#
# The first step is to setup the notebook and environment.
#
# We'll first import Eureka! along with some other useful packages.

# %%
import eureka
import os
import numpy as np

# %% [markdown]
# Next, we need to choose a short, meaningful label (without spaces) that describes the data we're currently working on. For simplicity, we will just set `eventlabel = 'miri_photometry'`. This same event label should be used throughout all stages.

# %%
eventlabel = 'miri_photometry'

# %% [markdown]
# To save time, we've also provided _rateints files produced from Stage 1 which would otherwise take 15+ minutes to produce (the exact runtime depends on your CPU and on whether multiple CPU threads are used). If you want to use those cached _rateints files, set `use_cached_s1` to `True`, otherwise set it to `False`.

# %%
use_cached_s1 = True

# %% [markdown]
# ---
# # Stage 1: jwst Pipeline (Eureka!'s wrapper)

# %% [markdown]
# ## Setting the Stage 1 "Eureka! Control File"
#
# Some of the parameters that might be worth varying are as follows:
#
# * `maximum_cores`: If want to limit the CPU usage of the stage, for example if you are running your data reduction on a shared sherver, you can set this to an integer number of cores or one of `'none'` (for single-threaded operations), `'quarter'`, `'half'`, or `'all'`.
# * `skip_firstframe`: This might be worth changing between `True`/`False`. The MIRI detectors show marked persistence effects, which manifest as deviations from linearity at the start of each ramp. To mitigate the effect of persistence on the measured countrates, this step flags the first group in every integration, instructing the pipeline to ignore the first group when fitting the ramps. For TSOs, this step is skipped by default (`skip_firstframe = True`), which does not remove the first frame. In theory it'd be best to set this to `False` (which removes the first group which is known to be noisy), but for integrations with small numbers of groups it might be worth setting to `True`. It is hard to say for sure without experimenting.
# * `skip_lastframe`: This might be worth changing between `True`/`False`. In the case of MIRI detectors, the array is reset during the last frame read in each integration, which results in a reduced level of accumulated counts in the last frame. By default, the pipeline applies this step to all MIRI data (`skip_firstframe = False`), flagging the last group in every integration as bad (as long as the number of groups per integration is greater than 2). This step is strongly recommended for TSOs (`skip_firstframe = False`), given that the last frame effect has been shown to vary from integration to integration. However, for integrations with a very small number of groups it might be worth setting to `True`. It is hard to say for sure without experimenting.
# * `skip_emicorr`: It could be worth changing this between `True`/`False`, but this likely won't have a very large impact. MIRI subarrays suffer from electromagnetic interference (EMI) noise patterns in the raw data that imprint periodic noise into each frame image, with the effect particularly apparent in the case of short ramps, which is typical of most MIRI TSOs. There are two algorithms that the pipeline can select from when applying this step: 'sequential' (the default) fits the EMI in the residuals from ramp fits, while 'joint' carries out a simultaneous fit to the ramps and EMI noise using a reference waveform for the EMI oscillations. The 'sequential' method typically requires 10 or more groups per integration for a reliable fit, while the 'joint' method has been demonstrated to successfully fit EMI noise for any ramp length. In practice, the background subtraction we'll do in Stage 3 ends up providing most of the benefits of this step, so it may not always be worth running. By default, the Eureka! pipeline skips this step (`skip_emicorr = True`), while the jwst pipeline's default is to run the step (`skip_emicorr = False`).
# * `skip_rscd`: It could be worth changing this between `True`/`False`. This step mitigates nonlinear behavior at the beginning of each ramp due to transient effects on the detector after every reset. While the exact causes of these effects are not fully understood, the severity of the nonlinearity scales with increasing signal, suggesting a type of persistence on the detectors. Currently, this step in the pipeline flags the first N groups at the beginning of all 2nd and higher integrations, where N is fixed to different values for different observing modes (e.g., N=4 in the case of MIRI LRS slitless TSOs). Due to the short ramps of most TSOs, this step is skipped by default (`skip_rscd = True`), as the flagging of a significant fraction of each ramp results in a steep reduction in the signal-to-noise ratio. However, if the TSO includes relatively large-amplitude features (e.g., exoplanet transits), and if the ramps are long enough to allow for the `rscd` step to be run, turning on this step can ameliorate biases in the relative flux levels due to the signal-dependent nonlinearity effects across the time series.
# * `skip_jump` & `jump_rejection_threshold`: The `jump` step flags outliers in the ramps due to cosmic ray hits. The algorithm uses an iterative process that examines the countrates between sequential pairs of groups and applies a sigma-clipping filter to flag groups that yield anomalously large countrates. The default sigma threshold used by the pipeline is `4.0`, though in practice, this settings results in a large number of false positives. Users are recommended to adjust the threshold to higher values (e.g., `8`-`10`) or skip this step altogether in favor of outlier masking at later stages of the data processing workflow. The threshold within Eureka! can be set with the `jump_rejection_threshold` parameter, and the step can be skipped by setting `skip_jump` to `True`.
# * `skip_dark_current`: By default this step is run for MIRI TSO observations and is likely best left to run (set the skip parameter to `False`), but it's possible better results could be obtained by experimenting with setting the skip parameter to `True`.
# * `skip_refpix`: By default this steps is run for MIRI TSO observations that are taken with the FULL array. For subarrays, including the LRS Slitless subarray, this step is automatically skpped and will not run even if set to `False`. It is possible better results could be obtained by experimenting with setting the skip parameters to `True` for data read with the FULL array.
#
# For more information on the options available in Stage 1, visit https://eurekadocs.readthedocs.io/en/latest/ecf.html#stage-1
#
# To change a parameter in the metadata class after it has been read-in, you can do something like the following:
# ```
# s1_meta.jump_rejection_threshold = 10.0
# ```

# %%
s1_ecf_contents = f"""
# Eureka! Control File for Stage 1: Detector Processing

# Stage 1 Documentation: https://eurekadocs.readthedocs.io/en/latest/ecf.html#stage-1

suffix                    uncal

pmap                      1364         # Setting a fixed pmap value to ensure consistency in reductions

maximum_cores             'all'        # Options are 'none', 'quarter', 'half', 'all', or any integer

# Pipeline stages
skip_emicorr              True         #### Might be worth experimenting with turning on/off
skip_saturation           False
skip_firstframe           False        #### Might be worth experimenting with turning on/off
skip_lastframe            False        #### Might be worth experimenting with turning on/off
skip_reset                False
skip_linearity            False
skip_rscd                 False        #### Might be worth experimenting with turning on/off
skip_dark_current         False        #### Might be worth experimenting with turning on/off
skip_refpix               False        #### Might be worth experimenting with turning on/off
skip_jump                 False
skip_clean_flicker_noise  True         #### Might be worth experimenting with turning on/off

#Pipeline stages parameters
jump_rejection_threshold  8.0          #### Might be worth experimenting with different values

# Diagnostics
isplots_S1                3
nplots                    5
hide_plots                False
verbose                   True

# Project directory
topdir                    ../miri_photometry/

# Directories relative to project dir
inputdir                  Uncalibrated
outputdir                 Stage1
"""

# This will save the ECF as a file that the next cell can read-in
with open(f'./S1_{eventlabel}.ecf', 'w') as f:
    f.write(s1_ecf_contents)

# %% [markdown]
# ## Running Stage 1

# %%
if use_cached_s1 or not os.path.exists('../miri_photometry/Stage1/S1_2025-04-21_miri_photometry_run1'):
    s1_meta = eureka.S1_detector_processing.s1_process.rampfitJWST(eventlabel, ecf_path='./')
# Out:
# Starting Stage 1 Processing
# Input directory: ../miri_photometry/Uncalibrated/
#   Found 10 data file(s) ending in uncal.fits
# Output directory: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/
# Copying S1 control file
# Starting file 1 of 10: jw01177011001_03101_00001-seg001_mirimage_uncal.fits
# 2025-04-29 19:04:02,721 - stpipe.EurekaS1Pipeline - INFO - EurekaS1Pipeline instance created.
# 2025-04-29 19:04:02,722 - stpipe.EurekaS1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2025-04-29 19:04:02,723 - stpipe.EurekaS1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2025-04-29 19:04:02,724 - stpipe.EurekaS1Pipeline.emicorr - INFO - EmiCorrStep instance created.
# 2025-04-29 19:04:02,725 - stpipe.EurekaS1Pipeline.saturation - INFO - SaturationStep instance created.
# 2025-04-29 19:04:02,726 - stpipe.EurekaS1Pipeline.ipc - INFO - IPCStep instance created.
# 2025-04-29 19:04:02,726 - stpipe.EurekaS1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2025-04-29 19:04:02,727 - stpipe.EurekaS1Pipeline.refpix - INFO - RefPixStep instance created.
# 2025-04-29 19:04:02,728 - stpipe.EurekaS1Pipeline.rscd - INFO - RscdStep instance created.
# 2025-04-29 19:04:02,729 - stpipe.EurekaS1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2025-04-29 19:04:02,729 - stpipe.EurekaS1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2025-04-29 19:04:02,730 - stpipe.EurekaS1Pipeline.linearity - INFO - LinearityStep instance created.
# 2025-04-29 19:04:02,731 - stpipe.EurekaS1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2025-04-29 19:04:02,732 - stpipe.EurekaS1Pipeline.reset - INFO - ResetStep instance created.
# 2025-04-29 19:04:02,732 - stpipe.EurekaS1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2025-04-29 19:04:02,733 - stpipe.EurekaS1Pipeline.charge_migration - INFO - ChargeMigrationStep instance created.
# 2025-04-29 19:04:02,734 - stpipe.EurekaS1Pipeline.jump - INFO - JumpStep instance created.
# 2025-04-29 19:04:02,735 - stpipe.EurekaS1Pipeline.clean_flicker_noise - INFO - CleanFlickerNoiseStep instance created.
# 2025-04-29 19:04:02,736 - stpipe.EurekaS1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2025-04-29 19:04:02,736 - stpipe.EurekaS1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2025-04-29 19:04:02,737 - stpipe.Eureka_SuperBiasStep - INFO - Eureka_SuperBiasStep instance created.
# 2025-04-29 19:04:02,738 - stpipe.Eureka_RampFitStep - INFO - Eureka_RampFitStep instance created.
# 2025-04-29 19:04:02,738 - stpipe - WARNING - /Users/hdiamondlowe/Functional/Science/Projects/JWebbinars/jwebbinar_prep/jwebbinar41/Eureka/src/eureka/S1_detector_processing/s1_process.py:235: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended. See https://jwst-pipeline.readthedocs.io/en/latest/jwst/user_documentation/running_pipeline_python.html#advanced-use-pipeline-run-vs-pipeline-call for more details.
#   self(filename)
#
# 2025-04-29 19:04:02,738 - stpipe - WARNING - /Users/hdiamondlowe/Programs/miniconda3/envs/eureka/lib/python3.13/site-packages/stpipe/step.py:580: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended.
#   warnings.warn(
#
# 2025-04-29 19:04:02,813 - stpipe.EurekaS1Pipeline - INFO - Step EurekaS1Pipeline running with args ('../miri_photometry/Uncalibrated/jw01177011001_03101_00001-seg001_mirimage_uncal.fits',).
# 2025-04-29 19:04:02,824 - stpipe.EurekaS1Pipeline - INFO - Step EurekaS1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       type: baseline
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: False
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: None
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 8.0
#       three_group_rejection_threshold: 6.0
#       four_group_rejection_threshold: 5.0
#       maximum_cores: all
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000.0
#       min_jump_to_flag_neighbors: 10.0
#       after_jump_flag_dn1: 0.0
#       after_jump_flag_time1: 0.0
#       after_jump_flag_dn2: 0.0
#       after_jump_flag_time2: 0.0
#       expand_large_events: False
#       min_sat_area: 1.0
#       min_jump_area: 5.0
#       expand_factor: 2.0
#       use_ellipses: False
#       sat_required_snowball: True
#       min_sat_radius_extend: 2.5
#       sat_expand: 2
#       edge_size: 25
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: False
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 1.2
#       extend_min_area: 90
#       extend_inner_radius: 1.0
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 15.0
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: all
#     gain_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2025-04-29 19:04:03,326 - stpipe.EurekaS1Pipeline - INFO - Prefetching reference files for dataset: 'jw01177011001_03101_00001-seg001_mirimage_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'sirskernel', 'superbias', 'trapdensity', 'trappars']
# 2025-04-29 19:04:03,328 - stpipe.EurekaS1Pipeline - INFO - Prefetch for DARK reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_dark_0103.fits'.
# 2025-04-29 19:04:03,329 - stpipe.EurekaS1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_gain_0048.fits'.
# 2025-04-29 19:04:03,329 - stpipe.EurekaS1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_linearity_0039.fits'.
# 2025-04-29 19:04:03,329 - stpipe.EurekaS1Pipeline - INFO - Prefetch for MASK reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_mask_0036.fits'.
# 2025-04-29 19:04:03,330 - stpipe.EurekaS1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2025-04-29 19:04:03,330 - stpipe.EurekaS1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_readnoise_0085.fits'.
# 2025-04-29 19:04:03,330 - stpipe.EurekaS1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2025-04-29 19:04:03,330 - stpipe.EurekaS1Pipeline - INFO - Prefetch for RESET reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_reset_0077.fits'.
# 2025-04-29 19:04:03,331 - stpipe.EurekaS1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits'.
# 2025-04-29 19:04:03,331 - stpipe.EurekaS1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_saturation_0034.fits'.
# 2025-04-29 19:04:03,331 - stpipe.EurekaS1Pipeline - INFO - Prefetch for SIRSKERNEL reference file is 'N/A'.
# 2025-04-29 19:04:03,331 - stpipe.EurekaS1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2025-04-29 19:04:03,331 - stpipe.EurekaS1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2025-04-29 19:04:03,332 - stpipe.EurekaS1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2025-04-29 19:04:03,356 - stpipe.EurekaS1Pipeline - INFO - Starting calwebb_detector1 ...
# 2025-04-29 19:04:04,225 - stpipe.EurekaS1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:04,228 - stpipe.EurekaS1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2025-04-29 19:04:04,229 - stpipe.EurekaS1Pipeline.group_scale - INFO - Step will be skipped
# 2025-04-29 19:04:04,230 - stpipe.EurekaS1Pipeline.group_scale - INFO - Step group_scale done
# 2025-04-29 19:04:04,326 - stpipe.EurekaS1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:04,335 - stpipe.EurekaS1Pipeline.dq_init - INFO - Using MASK reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_mask_0036.fits
# 2025-04-29 19:04:04,648 - stpipe.EurekaS1Pipeline.dq_init - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:04,659 - stpipe.EurekaS1Pipeline.dq_init - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:05,278 - stpipe.EurekaS1Pipeline.dq_init - INFO - Step dq_init done
# 2025-04-29 19:04:05,394 - stpipe.EurekaS1Pipeline.emicorr - INFO - Step emicorr running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:05,395 - stpipe.EurekaS1Pipeline.emicorr - INFO - Step skipped.
# 2025-04-29 19:04:05,464 - stpipe.EurekaS1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:05,474 - stpipe.EurekaS1Pipeline.saturation - INFO - Using SATURATION reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_saturation_0034.fits
# 2025-04-29 19:04:05,491 - stpipe.EurekaS1Pipeline.saturation - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:05,506 - stpipe.EurekaS1Pipeline.saturation - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:06,069 - stpipe.EurekaS1Pipeline.saturation - INFO - Using read_pattern with nframes 1
# 2025-04-29 19:04:08,351 - stpipe.EurekaS1Pipeline.saturation - INFO - Detected 2206 saturated pixels
# 2025-04-29 19:04:08,449 - stpipe.EurekaS1Pipeline.saturation - INFO - Detected 97 A/D floor pixels
# 2025-04-29 19:04:08,453 - stpipe.EurekaS1Pipeline.saturation - INFO - Step saturation done
# 2025-04-29 19:04:08,571 - stpipe.EurekaS1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:08,571 - stpipe.EurekaS1Pipeline.ipc - INFO - Step skipped.
# 2025-04-29 19:04:08,649 - stpipe.EurekaS1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:08,986 - stpipe.EurekaS1Pipeline.firstframe - INFO - Step firstframe done
# 2025-04-29 19:04:09,113 - stpipe.EurekaS1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:09,553 - stpipe.EurekaS1Pipeline.lastframe - INFO - Step lastframe done
# 2025-04-29 19:04:09,677 - stpipe.EurekaS1Pipeline.reset - INFO - Step reset running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:09,684 - stpipe.EurekaS1Pipeline.reset - INFO - Using RESET reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_reset_0077.fits
# 2025-04-29 19:04:09,723 - stpipe.EurekaS1Pipeline.reset - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:09,737 - stpipe.EurekaS1Pipeline.reset - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:10,298 - stpipe.EurekaS1Pipeline.reset - INFO - Step reset done
# 2025-04-29 19:04:10,433 - stpipe.EurekaS1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:10,442 - stpipe.EurekaS1Pipeline.linearity - INFO - Using Linearity reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_linearity_0039.fits
# 2025-04-29 19:04:10,459 - stpipe.EurekaS1Pipeline.linearity - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:10,471 - stpipe.EurekaS1Pipeline.linearity - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:12,434 - stpipe.EurekaS1Pipeline.linearity - INFO - Step linearity done
# 2025-04-29 19:04:12,574 - stpipe.EurekaS1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:12,584 - stpipe.EurekaS1Pipeline.rscd - INFO - Using RSCD reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits
# 2025-04-29 19:04:12,987 - stpipe.EurekaS1Pipeline.rscd - INFO - Number of groups to skip for integrations 2 and higher: 2
# 2025-04-29 19:04:12,998 - stpipe.EurekaS1Pipeline.rscd - INFO - Step rscd done
# 2025-04-29 19:04:13,136 - stpipe.EurekaS1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:13,146 - stpipe.EurekaS1Pipeline.dark_current - INFO - Using DARK reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_dark_0103.fits
# 2025-04-29 19:04:15,498 - stpipe.EurekaS1Pipeline.dark_current - INFO - Science data nints=40, ngroups=14, nframes=1, groupgap=0
# 2025-04-29 19:04:15,498 - stpipe.EurekaS1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=360, nframes=1, groupgap=0
# 2025-04-29 19:04:17,607 - stpipe.EurekaS1Pipeline.dark_current - INFO - Step dark_current done
# 2025-04-29 19:04:17,810 - stpipe.EurekaS1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:18,185 - stpipe.EurekaS1Pipeline.refpix - INFO - MIRI full frame data
# 2025-04-29 19:04:18,186 - stpipe.EurekaS1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2025-04-29 19:04:18,186 - stpipe.EurekaS1Pipeline.refpix - INFO - odd_even_rows = True
# 2025-04-29 19:04:18,186 - stpipe.EurekaS1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2025-04-29 19:04:18,187 - stpipe.EurekaS1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2025-04-29 19:04:18,187 - stpipe.EurekaS1Pipeline.refpix - INFO - odd_even_columns = False
# 2025-04-29 19:04:18,187 - stpipe.EurekaS1Pipeline.refpix - INFO - side_smoothing_length = False
# 2025-04-29 19:04:18,187 - stpipe.EurekaS1Pipeline.refpix - INFO - side_gain = False
# 2025-04-29 19:04:18,210 - stpipe.EurekaS1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2025-04-29 19:04:20,344 - stpipe.EurekaS1Pipeline.refpix - INFO - Adding initial read back in
# 2025-04-29 19:04:20,859 - stpipe.EurekaS1Pipeline.refpix - INFO - Step refpix done
# 2025-04-29 19:04:20,967 - stpipe.EurekaS1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:20,968 - stpipe.EurekaS1Pipeline.charge_migration - INFO - Step skipped.
# 2025-04-29 19:04:21,031 - stpipe.EurekaS1Pipeline.jump - INFO - Step jump running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:21,036 - stpipe.EurekaS1Pipeline.jump - INFO - CR rejection threshold = 8 sigma
# 2025-04-29 19:04:21,036 - stpipe.EurekaS1Pipeline.jump - INFO - Maximum cores to use = all
# 2025-04-29 19:04:21,299 - stpipe.EurekaS1Pipeline.jump - INFO - Using GAIN reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_gain_0048.fits
# 2025-04-29 19:04:21,303 - stpipe.EurekaS1Pipeline.jump - INFO - Using READNOISE reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2025-04-29 19:04:21,607 - stpipe.EurekaS1Pipeline.jump - INFO - Executing two-point difference method
# 2025-04-29 19:04:21,608 - stpipe.EurekaS1Pipeline.jump - INFO - Creating 16 processes for jump detection
# 2025-04-29 19:04:34,504 - stpipe.EurekaS1Pipeline.jump - INFO - Total elapsed time = 12.8965 sec
# 2025-04-29 19:04:34,880 - stpipe.EurekaS1Pipeline.jump - INFO - The execution time in seconds: 13.844769
# 2025-04-29 19:04:34,884 - stpipe.EurekaS1Pipeline.jump - INFO - Step jump done
# 2025-04-29 19:04:35,025 - stpipe.EurekaS1Pipeline.clean_flicker_noise - INFO - Step clean_flicker_noise running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:35,025 - stpipe.EurekaS1Pipeline.clean_flicker_noise - INFO - Step skipped.
# 2025-04-29 19:04:35,091 - stpipe.Eureka_RampFitStep - INFO - Step Eureka_RampFitStep running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:35,092 - stpipe.Eureka_RampFitStep - INFO - Step Eureka_RampFitStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   algorithm: OLS_C
#   int_name: ''
#   save_opt: False
#   opt_name: ''
#   suppress_one_group: True
#   firstgroup: None
#   lastgroup: None
#   maximum_cores: all
# 2025-04-29 19:04:35,106 - stpipe.Eureka_RampFitStep - INFO - Using READNOISE reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2025-04-29 19:04:35,114 - stpipe.Eureka_RampFitStep - INFO - Using GAIN reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_gain_0048.fits
# 2025-04-29 19:04:35,137 - stpipe.Eureka_RampFitStep - INFO - Using algorithm = OLS_C
# 2025-04-29 19:04:35,137 - stpipe.Eureka_RampFitStep - INFO - Using weighting = default
# 2025-04-29 19:04:37,722 - stpipe.Eureka_RampFitStep - INFO - Number of multiprocessing slices: 16
# 2025-04-29 19:04:37,815 - stpipe.Eureka_RampFitStep - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2025-04-29 19:04:37,820 - stpipe.Eureka_RampFitStep - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2025-04-29 19:04:37,824 - stpipe.Eureka_RampFitStep - INFO - Number of processors used for multiprocessing: 16
# 2025-04-29 19:04:43,283 - stpipe.Eureka_RampFitStep - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-04-29 19:04:43,284 - stpipe.Eureka_RampFitStep - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-04-29 19:04:43,285 - stpipe.Eureka_RampFitStep - INFO - Step Eureka_RampFitStep done
# 2025-04-29 19:04:43,285 - stpipe.EurekaS1Pipeline - INFO - Results used jwst version: 1.18.0
# 2025-04-29 19:04:43,421 - stpipe.EurekaS1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:43,437 - stpipe.EurekaS1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2025-04-29 19:04:43,437 - stpipe.EurekaS1Pipeline.gain_scale - INFO - Step will be skipped
# 2025-04-29 19:04:43,439 - stpipe.EurekaS1Pipeline.gain_scale - INFO - Step gain_scale done
# 2025-04-29 19:04:43,502 - stpipe.EurekaS1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(40, 1024, 1032) from jw01177011001_03101_00001-seg001_mirimage_uncal.fits>,).
# 2025-04-29 19:04:43,518 - stpipe.EurekaS1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2025-04-29 19:04:43,518 - stpipe.EurekaS1Pipeline.gain_scale - INFO - Step will be skipped
# 2025-04-29 19:04:43,520 - stpipe.EurekaS1Pipeline.gain_scale - INFO - Step gain_scale done
# 2025-04-29 19:04:43,825 - stpipe.EurekaS1Pipeline - INFO - Saved model in ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg001_mirimage_rateints.fits
# 2025-04-29 19:04:43,825 - stpipe.EurekaS1Pipeline - INFO - ... ending calwebb_detector1
# 2025-04-29 19:04:43,839 - stpipe.EurekaS1Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-04-29 19:04:43,880 - stpipe.EurekaS1Pipeline - INFO - Saved model in ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg001_mirimage_rate.fits
# 2025-04-29 19:04:43,880 - stpipe.EurekaS1Pipeline - INFO - Step EurekaS1Pipeline done
# 2025-04-29 19:04:43,881 - stpipe - INFO - Results used jwst version: 1.18.0
# Starting file 2 of 10: jw01177011001_03101_00001-seg002_mirimage_uncal.fits
# 2025-04-29 19:04:43,896 - stpipe.EurekaS1Pipeline - INFO - EurekaS1Pipeline instance created.
# 2025-04-29 19:04:43,896 - stpipe.EurekaS1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2025-04-29 19:04:43,897 - stpipe.EurekaS1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2025-04-29 19:04:43,897 - stpipe.EurekaS1Pipeline.emicorr - INFO - EmiCorrStep instance created.
# 2025-04-29 19:04:43,898 - stpipe.EurekaS1Pipeline.saturation - INFO - SaturationStep instance created.
# 2025-04-29 19:04:43,898 - stpipe.EurekaS1Pipeline.ipc - INFO - IPCStep instance created.
# 2025-04-29 19:04:43,899 - stpipe.EurekaS1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2025-04-29 19:04:43,900 - stpipe.EurekaS1Pipeline.refpix - INFO - RefPixStep instance created.
# 2025-04-29 19:04:43,900 - stpipe.EurekaS1Pipeline.rscd - INFO - RscdStep instance created.
# 2025-04-29 19:04:43,901 - stpipe.EurekaS1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2025-04-29 19:04:43,901 - stpipe.EurekaS1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2025-04-29 19:04:43,902 - stpipe.EurekaS1Pipeline.linearity - INFO - LinearityStep instance created.
# 2025-04-29 19:04:43,902 - stpipe.EurekaS1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2025-04-29 19:04:43,903 - stpipe.EurekaS1Pipeline.reset - INFO - ResetStep instance created.
# 2025-04-29 19:04:43,903 - stpipe.EurekaS1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2025-04-29 19:04:43,904 - stpipe.EurekaS1Pipeline.charge_migration - INFO - ChargeMigrationStep instance created.
# 2025-04-29 19:04:43,905 - stpipe.EurekaS1Pipeline.jump - INFO - JumpStep instance created.
# 2025-04-29 19:04:43,905 - stpipe.EurekaS1Pipeline.clean_flicker_noise - INFO - CleanFlickerNoiseStep instance created.
# 2025-04-29 19:04:43,906 - stpipe.EurekaS1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2025-04-29 19:04:43,907 - stpipe.EurekaS1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2025-04-29 19:04:43,907 - stpipe.Eureka_SuperBiasStep - INFO - Eureka_SuperBiasStep instance created.
# 2025-04-29 19:04:43,908 - stpipe.Eureka_RampFitStep - INFO - Eureka_RampFitStep instance created.
# 2025-04-29 19:04:43,908 - stpipe - WARNING - /Users/hdiamondlowe/Functional/Science/Projects/JWebbinars/jwebbinar_prep/jwebbinar41/Eureka/src/eureka/S1_detector_processing/s1_process.py:235: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended. See https://jwst-pipeline.readthedocs.io/en/latest/jwst/user_documentation/running_pipeline_python.html#advanced-use-pipeline-run-vs-pipeline-call for more details.
#   self(filename)
#
# 2025-04-29 19:04:43,908 - stpipe - WARNING - /Users/hdiamondlowe/Programs/miniconda3/envs/eureka/lib/python3.13/site-packages/stpipe/step.py:580: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended.
#   warnings.warn(
#
# 2025-04-29 19:04:43,978 - stpipe.EurekaS1Pipeline - INFO - Step EurekaS1Pipeline running with args ('../miri_photometry/Uncalibrated/jw01177011001_03101_00001-seg002_mirimage_uncal.fits',).
# 2025-04-29 19:04:43,988 - stpipe.EurekaS1Pipeline - INFO - Step EurekaS1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       type: baseline
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: False
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: None
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 8.0
#       three_group_rejection_threshold: 6.0
#       four_group_rejection_threshold: 5.0
#       maximum_cores: all
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000.0
#       min_jump_to_flag_neighbors: 10.0
#       after_jump_flag_dn1: 0.0
#       after_jump_flag_time1: 0.0
#       after_jump_flag_dn2: 0.0
#       after_jump_flag_time2: 0.0
#       expand_large_events: False
#       min_sat_area: 1.0
#       min_jump_area: 5.0
#       expand_factor: 2.0
#       use_ellipses: False
#       sat_required_snowball: True
#       min_sat_radius_extend: 2.5
#       sat_expand: 2
#       edge_size: 25
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: False
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 1.2
#       extend_min_area: 90
#       extend_inner_radius: 1.0
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 15.0
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: all
#     gain_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2025-04-29 19:04:44,445 - stpipe.EurekaS1Pipeline - INFO - Prefetching reference files for dataset: 'jw01177011001_03101_00001-seg002_mirimage_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'sirskernel', 'superbias', 'trapdensity', 'trappars']
# 2025-04-29 19:04:44,447 - stpipe.EurekaS1Pipeline - INFO - Prefetch for DARK reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_dark_0103.fits'.
# 2025-04-29 19:04:44,447 - stpipe.EurekaS1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_gain_0048.fits'.
# 2025-04-29 19:04:44,448 - stpipe.EurekaS1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_linearity_0039.fits'.
# 2025-04-29 19:04:44,448 - stpipe.EurekaS1Pipeline - INFO - Prefetch for MASK reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_mask_0036.fits'.
# 2025-04-29 19:04:44,448 - stpipe.EurekaS1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2025-04-29 19:04:44,448 - stpipe.EurekaS1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_readnoise_0085.fits'.
# 2025-04-29 19:04:44,449 - stpipe.EurekaS1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2025-04-29 19:04:44,449 - stpipe.EurekaS1Pipeline - INFO - Prefetch for RESET reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_reset_0077.fits'.
# 2025-04-29 19:04:44,449 - stpipe.EurekaS1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits'.
# 2025-04-29 19:04:44,449 - stpipe.EurekaS1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_saturation_0034.fits'.
# 2025-04-29 19:04:44,449 - stpipe.EurekaS1Pipeline - INFO - Prefetch for SIRSKERNEL reference file is 'N/A'.
# 2025-04-29 19:04:44,449 - stpipe.EurekaS1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2025-04-29 19:04:44,450 - stpipe.EurekaS1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2025-04-29 19:04:44,450 - stpipe.EurekaS1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2025-04-29 19:04:44,473 - stpipe.EurekaS1Pipeline - INFO - Starting calwebb_detector1 ...
# 2025-04-29 19:04:45,396 - stpipe.EurekaS1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg002_mirimage_uncal.fits>,).
# 2025-04-29 19:04:45,401 - stpipe.EurekaS1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2025-04-29 19:04:45,401 - stpipe.EurekaS1Pipeline.group_scale - INFO - Step will be skipped
# 2025-04-29 19:04:45,402 - stpipe.EurekaS1Pipeline.group_scale - INFO - Step group_scale done
# 2025-04-29 19:04:45,510 - stpipe.EurekaS1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg002_mirimage_uncal.fits>,).
# 2025-04-29 19:04:45,519 - stpipe.EurekaS1Pipeline.dq_init - INFO - Using MASK reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_mask_0036.fits
# 2025-04-29 19:04:45,916 - stpipe.EurekaS1Pipeline.dq_init - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:45,929 - stpipe.EurekaS1Pipeline.dq_init - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:46,324 - stpipe.EurekaS1Pipeline.dq_init - INFO - Step dq_init done
# 2025-04-29 19:04:46,446 - stpipe.EurekaS1Pipeline.emicorr - INFO - Step emicorr running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg002_mirimage_uncal.fits>,).
# 2025-04-29 19:04:46,447 - stpipe.EurekaS1Pipeline.emicorr - INFO - Step skipped.
# 2025-04-29 19:04:46,521 - stpipe.EurekaS1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg002_mirimage_uncal.fits>,).
# 2025-04-29 19:04:46,530 - stpipe.EurekaS1Pipeline.saturation - INFO - Using SATURATION reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_saturation_0034.fits
# 2025-04-29 19:04:46,545 - stpipe.EurekaS1Pipeline.saturation - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:46,558 - stpipe.EurekaS1Pipeline.saturation - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:46,985 - stpipe.EurekaS1Pipeline.saturation - INFO - Using read_pattern with nframes 1
# 2025-04-29 19:04:49,684 - stpipe.EurekaS1Pipeline.saturation - INFO - Detected 353 saturated pixels
# 2025-04-29 19:04:49,787 - stpipe.EurekaS1Pipeline.saturation - INFO - Detected 74 A/D floor pixels
# 2025-04-29 19:04:49,791 - stpipe.EurekaS1Pipeline.saturation - INFO - Step saturation done
# 2025-04-29 19:04:49,925 - stpipe.EurekaS1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg002_mirimage_uncal.fits>,).
# 2025-04-29 19:04:49,925 - stpipe.EurekaS1Pipeline.ipc - INFO - Step skipped.
# 2025-04-29 19:04:50,002 - stpipe.EurekaS1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg002_mirimage_uncal.fits>,).
# 2025-04-29 19:04:50,356 - stpipe.EurekaS1Pipeline.firstframe - INFO - Step firstframe done
# 2025-04-29 19:04:50,501 - stpipe.EurekaS1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg002_mirimage_uncal.fits>,).
# 2025-04-29 19:04:50,936 - stpipe.EurekaS1Pipeline.lastframe - INFO - Step lastframe done
# 2025-04-29 19:04:51,081 - stpipe.EurekaS1Pipeline.reset - INFO - Step reset running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg002_mirimage_uncal.fits>,).
# 2025-04-29 19:04:51,090 - stpipe.EurekaS1Pipeline.reset - INFO - Using RESET reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_reset_0077.fits
# 2025-04-29 19:04:51,134 - stpipe.EurekaS1Pipeline.reset - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:51,147 - stpipe.EurekaS1Pipeline.reset - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:51,700 - stpipe.EurekaS1Pipeline.reset - INFO - Step reset done
# 2025-04-29 19:04:51,844 - stpipe.EurekaS1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg002_mirimage_uncal.fits>,).
# 2025-04-29 19:04:51,853 - stpipe.EurekaS1Pipeline.linearity - INFO - Using Linearity reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_linearity_0039.fits
# 2025-04-29 19:04:51,872 - stpipe.EurekaS1Pipeline.linearity - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:51,880 - stpipe.EurekaS1Pipeline.linearity - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:04:53,867 - stpipe.EurekaS1Pipeline.linearity - INFO - Step linearity done
# 2025-04-29 19:04:54,004 - stpipe.EurekaS1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(40, 14, 1024, 1032) from jw01177011001_03101_00001-seg002_mirimage_uncal.fits>,).
# 2025-04-29 19:04:54,013 - stpipe.EurekaS1Pipeline.rscd - INFO - Using RSCD reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits
# 2025-04-29 19:04:54,388 - stpipe.EurekaS1Pipeline.rscd - INFO - Number of groups to skip for integrations 2 and higher: 2
# ...
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2025-04-29 19:10:23,476 - stpipe.EurekaS1Pipeline - INFO - Prefetching reference files for dataset: 'jw01177011001_03101_00001-seg010_mirimage_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'sirskernel', 'superbias', 'trapdensity', 'trappars']
# 2025-04-29 19:10:23,479 - stpipe.EurekaS1Pipeline - INFO - Prefetch for DARK reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_dark_0103.fits'.
# 2025-04-29 19:10:23,480 - stpipe.EurekaS1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_gain_0048.fits'.
# 2025-04-29 19:10:23,480 - stpipe.EurekaS1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_linearity_0039.fits'.
# 2025-04-29 19:10:23,480 - stpipe.EurekaS1Pipeline - INFO - Prefetch for MASK reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_mask_0036.fits'.
# 2025-04-29 19:10:23,481 - stpipe.EurekaS1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2025-04-29 19:10:23,481 - stpipe.EurekaS1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_readnoise_0085.fits'.
# 2025-04-29 19:10:23,481 - stpipe.EurekaS1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2025-04-29 19:10:23,482 - stpipe.EurekaS1Pipeline - INFO - Prefetch for RESET reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_reset_0077.fits'.
# 2025-04-29 19:10:23,482 - stpipe.EurekaS1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits'.
# 2025-04-29 19:10:23,482 - stpipe.EurekaS1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_saturation_0034.fits'.
# 2025-04-29 19:10:23,483 - stpipe.EurekaS1Pipeline - INFO - Prefetch for SIRSKERNEL reference file is 'N/A'.
# 2025-04-29 19:10:23,483 - stpipe.EurekaS1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2025-04-29 19:10:23,484 - stpipe.EurekaS1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2025-04-29 19:10:23,484 - stpipe.EurekaS1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2025-04-29 19:10:23,496 - stpipe.EurekaS1Pipeline - INFO - Starting calwebb_detector1 ...
# 2025-04-29 19:10:24,093 - stpipe.EurekaS1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:24,098 - stpipe.EurekaS1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2025-04-29 19:10:24,099 - stpipe.EurekaS1Pipeline.group_scale - INFO - Step will be skipped
# 2025-04-29 19:10:24,100 - stpipe.EurekaS1Pipeline.group_scale - INFO - Step group_scale done
# 2025-04-29 19:10:24,211 - stpipe.EurekaS1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:24,221 - stpipe.EurekaS1Pipeline.dq_init - INFO - Using MASK reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_mask_0036.fits
# 2025-04-29 19:10:24,387 - stpipe.EurekaS1Pipeline.dq_init - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:10:24,408 - stpipe.EurekaS1Pipeline.dq_init - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:10:24,619 - stpipe.EurekaS1Pipeline.dq_init - INFO - Step dq_init done
# 2025-04-29 19:10:24,740 - stpipe.EurekaS1Pipeline.emicorr - INFO - Step emicorr running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:24,741 - stpipe.EurekaS1Pipeline.emicorr - INFO - Step skipped.
# 2025-04-29 19:10:24,859 - stpipe.EurekaS1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:24,869 - stpipe.EurekaS1Pipeline.saturation - INFO - Using SATURATION reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_saturation_0034.fits
# 2025-04-29 19:10:24,891 - stpipe.EurekaS1Pipeline.saturation - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:10:24,908 - stpipe.EurekaS1Pipeline.saturation - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:10:25,073 - stpipe.EurekaS1Pipeline.saturation - INFO - Using read_pattern with nframes 1
# 2025-04-29 19:10:26,362 - stpipe.EurekaS1Pipeline.saturation - INFO - Detected 296 saturated pixels
# 2025-04-29 19:10:26,394 - stpipe.EurekaS1Pipeline.saturation - INFO - Detected 66 A/D floor pixels
# 2025-04-29 19:10:26,399 - stpipe.EurekaS1Pipeline.saturation - INFO - Step saturation done
# 2025-04-29 19:10:26,503 - stpipe.EurekaS1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:26,503 - stpipe.EurekaS1Pipeline.ipc - INFO - Step skipped.
# 2025-04-29 19:10:26,575 - stpipe.EurekaS1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:26,681 - stpipe.EurekaS1Pipeline.firstframe - INFO - Step firstframe done
# 2025-04-29 19:10:26,802 - stpipe.EurekaS1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:26,943 - stpipe.EurekaS1Pipeline.lastframe - INFO - Step lastframe done
# 2025-04-29 19:10:27,054 - stpipe.EurekaS1Pipeline.reset - INFO - Step reset running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:27,063 - stpipe.EurekaS1Pipeline.reset - INFO - Using RESET reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_reset_0077.fits
# 2025-04-29 19:10:27,108 - stpipe.EurekaS1Pipeline.reset - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:10:27,117 - stpipe.EurekaS1Pipeline.reset - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:10:27,271 - stpipe.EurekaS1Pipeline.reset - INFO - Step reset done
# 2025-04-29 19:10:27,376 - stpipe.EurekaS1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:27,385 - stpipe.EurekaS1Pipeline.linearity - INFO - Using Linearity reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_linearity_0039.fits
# 2025-04-29 19:10:27,406 - stpipe.EurekaS1Pipeline.linearity - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:10:27,419 - stpipe.EurekaS1Pipeline.linearity - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-04-29 19:10:28,244 - stpipe.EurekaS1Pipeline.linearity - INFO - Step linearity done
# 2025-04-29 19:10:28,370 - stpipe.EurekaS1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:28,378 - stpipe.EurekaS1Pipeline.rscd - INFO - Using RSCD reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits
# 2025-04-29 19:10:28,499 - stpipe.EurekaS1Pipeline.rscd - INFO - Number of groups to skip for integrations 2 and higher: 2
# 2025-04-29 19:10:28,505 - stpipe.EurekaS1Pipeline.rscd - INFO - Step rscd done
# 2025-04-29 19:10:28,605 - stpipe.EurekaS1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:28,613 - stpipe.EurekaS1Pipeline.dark_current - INFO - Using DARK reference file /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_dark_0103.fits
# 2025-04-29 19:10:29,898 - stpipe.EurekaS1Pipeline.dark_current - INFO - Science data nints=17, ngroups=14, nframes=1, groupgap=0
# 2025-04-29 19:10:29,899 - stpipe.EurekaS1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=360, nframes=1, groupgap=0
# 2025-04-29 19:10:30,538 - stpipe.EurekaS1Pipeline.dark_current - INFO - Step dark_current done
# 2025-04-29 19:10:30,725 - stpipe.EurekaS1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:30,845 - stpipe.EurekaS1Pipeline.refpix - INFO - MIRI full frame data
# 2025-04-29 19:10:30,845 - stpipe.EurekaS1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2025-04-29 19:10:30,845 - stpipe.EurekaS1Pipeline.refpix - INFO - odd_even_rows = True
# 2025-04-29 19:10:30,846 - stpipe.EurekaS1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2025-04-29 19:10:30,846 - stpipe.EurekaS1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2025-04-29 19:10:30,846 - stpipe.EurekaS1Pipeline.refpix - INFO - odd_even_columns = False
# 2025-04-29 19:10:30,846 - stpipe.EurekaS1Pipeline.refpix - INFO - side_smoothing_length = False
# 2025-04-29 19:10:30,846 - stpipe.EurekaS1Pipeline.refpix - INFO - side_gain = False
# 2025-04-29 19:10:30,855 - stpipe.EurekaS1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2025-04-29 19:10:31,764 - stpipe.EurekaS1Pipeline.refpix - INFO - Adding initial read back in
# 2025-04-29 19:10:31,987 - stpipe.EurekaS1Pipeline.refpix - INFO - Step refpix done
# 2025-04-29 19:10:32,077 - stpipe.EurekaS1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:32,077 - stpipe.EurekaS1Pipeline.charge_migration - INFO - Step skipped.
# 2025-04-29 19:10:32,143 - stpipe.EurekaS1Pipeline.jump - INFO - Step jump running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:32,147 - stpipe.EurekaS1Pipeline.jump - INFO - CR rejection threshold = 8 sigma
# 2025-04-29 19:10:32,148 - stpipe.EurekaS1Pipeline.jump - INFO - Maximum cores to use = all
# 2025-04-29 19:10:32,252 - stpipe.EurekaS1Pipeline.jump - INFO - Using GAIN reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_gain_0048.fits
# 2025-04-29 19:10:32,257 - stpipe.EurekaS1Pipeline.jump - INFO - Using READNOISE reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2025-04-29 19:10:32,381 - stpipe.EurekaS1Pipeline.jump - INFO - Executing two-point difference method
# 2025-04-29 19:10:32,381 - stpipe.EurekaS1Pipeline.jump - INFO - Creating 16 processes for jump detection
# 2025-04-29 19:10:36,936 - stpipe.EurekaS1Pipeline.jump - INFO - Total elapsed time = 4.55491 sec
# 2025-04-29 19:10:37,116 - stpipe.EurekaS1Pipeline.jump - INFO - The execution time in seconds: 4.968836
# 2025-04-29 19:10:37,120 - stpipe.EurekaS1Pipeline.jump - INFO - Step jump done
# 2025-04-29 19:10:37,240 - stpipe.EurekaS1Pipeline.clean_flicker_noise - INFO - Step clean_flicker_noise running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:37,241 - stpipe.EurekaS1Pipeline.clean_flicker_noise - INFO - Step skipped.
# 2025-04-29 19:10:37,337 - stpipe.Eureka_RampFitStep - INFO - Step Eureka_RampFitStep running with args (<RampModel(17, 14, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:37,338 - stpipe.Eureka_RampFitStep - INFO - Step Eureka_RampFitStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   algorithm: OLS_C
#   int_name: ''
#   save_opt: False
#   opt_name: ''
#   suppress_one_group: True
#   firstgroup: None
#   lastgroup: None
#   maximum_cores: all
# 2025-04-29 19:10:37,352 - stpipe.Eureka_RampFitStep - INFO - Using READNOISE reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2025-04-29 19:10:37,353 - stpipe.Eureka_RampFitStep - INFO - Using GAIN reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_gain_0048.fits
# 2025-04-29 19:10:37,368 - stpipe.Eureka_RampFitStep - INFO - Using algorithm = OLS_C
# 2025-04-29 19:10:37,369 - stpipe.Eureka_RampFitStep - INFO - Using weighting = default
# 2025-04-29 19:10:38,520 - stpipe.Eureka_RampFitStep - INFO - Number of multiprocessing slices: 16
# 2025-04-29 19:10:38,597 - stpipe.Eureka_RampFitStep - INFO - Number of leading groups that are flagged as DO_NOT_USE: 2
# 2025-04-29 19:10:38,599 - stpipe.Eureka_RampFitStep - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2025-04-29 19:10:38,601 - stpipe.Eureka_RampFitStep - INFO - Number of processors used for multiprocessing: 16
# 2025-04-29 19:10:40,361 - stpipe.Eureka_RampFitStep - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-04-29 19:10:40,363 - stpipe.Eureka_RampFitStep - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-04-29 19:10:40,363 - stpipe.Eureka_RampFitStep - INFO - Step Eureka_RampFitStep done
# 2025-04-29 19:10:40,363 - stpipe.EurekaS1Pipeline - INFO - Results used jwst version: 1.18.0
# 2025-04-29 19:10:40,469 - stpipe.EurekaS1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:40,486 - stpipe.EurekaS1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2025-04-29 19:10:40,486 - stpipe.EurekaS1Pipeline.gain_scale - INFO - Step will be skipped
# 2025-04-29 19:10:40,488 - stpipe.EurekaS1Pipeline.gain_scale - INFO - Step gain_scale done
# 2025-04-29 19:10:40,557 - stpipe.EurekaS1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(17, 1024, 1032) from jw01177011001_03101_00001-seg010_mirimage_uncal.fits>,).
# 2025-04-29 19:10:40,573 - stpipe.EurekaS1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2025-04-29 19:10:40,574 - stpipe.EurekaS1Pipeline.gain_scale - INFO - Step will be skipped
# 2025-04-29 19:10:40,576 - stpipe.EurekaS1Pipeline.gain_scale - INFO - Step gain_scale done
# 2025-04-29 19:10:40,739 - stpipe.EurekaS1Pipeline - INFO - Saved model in ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg010_mirimage_rateints.fits
# 2025-04-29 19:10:40,739 - stpipe.EurekaS1Pipeline - INFO - ... ending calwebb_detector1
# 2025-04-29 19:10:40,746 - stpipe.EurekaS1Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-04-29 19:10:40,781 - stpipe.EurekaS1Pipeline - INFO - Saved model in ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg010_mirimage_rate.fits
# 2025-04-29 19:10:40,782 - stpipe.EurekaS1Pipeline - INFO - Step EurekaS1Pipeline done
# 2025-04-29 19:10:40,782 - stpipe - INFO - Results used jwst version: 1.18.0
# Total time (min): 6.64
# Saving Metadata

# %% [markdown]
# ---
# # Stage 2: jwst Pipeline (Eureka!'s wrapper)

# %% [markdown]
# ## Setting up the Stage 2 "Eureka! Control File"
#
# For MIRI TSO data, there is very little of importance in Stage 2. The main steps of note are:
# * `assign_wcs`: This non-optional step is what assigns the RA and Dec solution to your photometry.
# * `flat_field`: This step calibrates non-uniform illumination and response of different pixels. Given that JWST TSO data is typically extremely stable in position over time, this step often isn't very important for TSO data one way or the other as long as you aren't producing absolutely calibrated data.
# * `photom`: This step converts the units of the images from the measurement units related to Data Numbers to physical units of MJy/sr. Since TSO data generally doesn't require absolutely calibrated fluxes, we normally skip this step (by setting `skip_photom` to `True`) for exoplanet data. This has the added advantage of more easily being able to estimate the uncertainties in the time series later on. However, if you want to produce an absolutely calibrated spectrum of the host star in order to compare the observed stellar flux with stellar models, then the `photom` step should be turned on.

# %%
s2_ecf_contents = f"""
# Eureka! Control File for Stage 2: Data Reduction

# Stage 2 Documentation: https://eurekadocs.readthedocs.io/en/latest/ecf.html#stage-2

suffix          rateints    # Data file suffix

pmap            1364        # Setting a fixed pmap value to ensure consistency in reductions

# Note: different instruments and modes will use different steps by default
skip_flat_field False       #### Might be worth experimenting with turning on/off
skip_photom     True        # Strongly recommended to skip (unless doing flux calibrated photometry) in order to get better uncertainties out of Stage 3.

# Diagnostics
hide_plots      False       # If True, plots will automatically be closed rather than popping up

# Project directory
topdir          ../miri_photometry/

# Directories relative to project dir
inputdir        Stage1
outputdir       Stage2
"""

# This will save the ECF as a file that the next cell can read-in
with open(f'./S2_{eventlabel}.ecf', 'w') as f:
    f.write(s2_ecf_contents)

# %% [markdown]
# ## Running Stage 2
#
# For these particular data, running Stage 2 should take ~2 minutes, though the exact runtime depends on your specific CPU

# %%
s2_meta = eureka.S2_calibrations.s2_calibrate.calibrateJWST(eventlabel, ecf_path='./')
# Out:
# WARNING: There are 2 metadata save files in the folder: ../miri_photometry/Stage1/
#   Using the metadata file inside: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/
#   and will consider aperture ranges listed there. If this metadata file is not a part
#   of the run you intended, please provide a more precise folder for the metadata file.
#
# Starting Stage 2 Reduction
# Input directory: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/
#   Found 10 data file(s) ending in rateints.fits
# Output directory: ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/
# Copying S2 control file
# 2025-04-29 19:13:53,967 - stpipe.EurekaImage2Pipeline - INFO - EurekaImage2Pipeline instance created.
# 2025-04-29 19:13:53,969 - stpipe.EurekaImage2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2025-04-29 19:13:53,970 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2025-04-29 19:13:53,970 - stpipe.EurekaImage2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2025-04-29 19:13:53,971 - stpipe.EurekaImage2Pipeline.photom - INFO - PhotomStep instance created.
# 2025-04-29 19:13:53,972 - stpipe.EurekaImage2Pipeline.resample - INFO - ResampleStep instance created.
# Starting file 1 of 10
# Running the Image2Pipeline
# 2025-04-29 19:13:53,984 - stpipe - WARNING - /Users/hdiamondlowe/Functional/Science/Projects/JWebbinars/jwebbinar_prep/jwebbinar41/Eureka/src/eureka/S2_calibrations/s2_calibrate.py:349: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended. See https://jwst-pipeline.readthedocs.io/en/latest/jwst/user_documentation/running_pipeline_python.html#advanced-use-pipeline-run-vs-pipeline-call for more details.
#   self(filename)
#
# 2025-04-29 19:13:53,985 - stpipe - WARNING - /Users/hdiamondlowe/Programs/miniconda3/envs/eureka/lib/python3.13/site-packages/stpipe/step.py:580: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended.
#   warnings.warn(
#
# 2025-04-29 19:13:54,059 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline running with args ('../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg001_mirimage_rateints.fits',).
# 2025-04-29 19:13:54,063 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       mrs_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: ivm
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
# 2025-04-29 19:13:54,242 - stpipe.EurekaImage2Pipeline - INFO - Prefetching reference files for dataset: 'jw01177011001_03101_00001-seg001_mirimage_rateints.fits' reftypes = ['camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2025-04-29 19:13:54,244 - CRDS - INFO -  Fetching  /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf   12.4 K bytes  (1 / 3 files) (0 / 12.7 M bytes)
# 2025-04-29 19:13:54,414 - CRDS - INFO -  Fetching  /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf    2.5 K bytes  (2 / 3 files) (12.4 K / 12.7 M bytes)
# 2025-04-29 19:13:54,568 - CRDS - INFO -  Fetching  /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_flat_0828.fits   12.7 M bytes  (3 / 3 files) (14.8 K / 12.7 M bytes)
# 2025-04-29 19:13:57,978 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2025-04-29 19:13:57,980 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2025-04-29 19:13:57,980 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2025-04-29 19:13:57,981 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2025-04-29 19:13:57,982 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2025-04-29 19:13:57,983 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2025-04-29 19:13:57,984 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2025-04-29 19:13:57,985 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_flat_0828.fits'.
# 2025-04-29 19:13:57,986 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2025-04-29 19:13:57,987 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2025-04-29 19:13:57,987 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2025-04-29 19:13:57,988 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2025-04-29 19:13:57,988 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2025-04-29 19:13:57,988 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2025-04-29 19:13:57,989 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2025-04-29 19:13:57,990 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2025-04-29 19:13:57,990 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2025-04-29 19:13:57,991 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2025-04-29 19:13:57,991 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2025-04-29 19:13:57,992 - stpipe.EurekaImage2Pipeline - INFO - Starting calwebb_image2 ...
# 2025-04-29 19:13:57,993 - stpipe.EurekaImage2Pipeline - INFO - Processing product ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg001_mirimage
# 2025-04-29 19:13:57,994 - stpipe.EurekaImage2Pipeline - INFO - Working on input ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg001_mirimage_rateints.fits ...
# 2025-04-29 19:13:58,231 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg001_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:13:58,328 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2025-04-29 19:13:58,431 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  346.619818039 -5.069619139 346.649683740 -5.059965021 346.639989701 -5.030072760 346.609986527 -5.039467155
# 2025-04-29 19:13:58,431 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  346.619818039 -5.069619139 346.649683740 -5.059965021 346.639989701 -5.030072760 346.609986527 -5.039467155
# 2025-04-29 19:13:58,432 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2025-04-29 19:13:58,458 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2025-04-29 19:13:58,549 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg001_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:13:58,585 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Using FLAT reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_flat_0828.fits
# 2025-04-29 19:13:58,586 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2025-04-29 19:13:58,586 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2025-04-29 19:13:58,586 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2025-04-29 19:13:59,039 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Step flat_field done
# 2025-04-29 19:13:59,129 - stpipe.EurekaImage2Pipeline.photom - INFO - Step photom running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg001_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:13:59,129 - stpipe.EurekaImage2Pipeline.photom - INFO - Step skipped.
# 2025-04-29 19:13:59,130 - stpipe.EurekaImage2Pipeline - INFO - Finished processing product ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg001_mirimage
# 2025-04-29 19:13:59,130 - stpipe.EurekaImage2Pipeline - INFO - ... ending calwebb_image2
# 2025-04-29 19:13:59,131 - stpipe.EurekaImage2Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-04-29 19:13:59,397 - stpipe.EurekaImage2Pipeline - INFO - Saved model in ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg001_mirimage_calints.fits
# 2025-04-29 19:13:59,397 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline done
# 2025-04-29 19:13:59,397 - stpipe - INFO - Results used jwst version: 1.18.0
# Starting file 2 of 10
# Running the Image2Pipeline
# 2025-04-29 19:13:59,421 - stpipe - WARNING - /Users/hdiamondlowe/Functional/Science/Projects/JWebbinars/jwebbinar_prep/jwebbinar41/Eureka/src/eureka/S2_calibrations/s2_calibrate.py:349: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended. See https://jwst-pipeline.readthedocs.io/en/latest/jwst/user_documentation/running_pipeline_python.html#advanced-use-pipeline-run-vs-pipeline-call for more details.
#   self(filename)
#
# 2025-04-29 19:13:59,421 - stpipe - WARNING - /Users/hdiamondlowe/Programs/miniconda3/envs/eureka/lib/python3.13/site-packages/stpipe/step.py:580: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended.
#   warnings.warn(
#
# 2025-04-29 19:13:59,497 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline running with args ('../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg002_mirimage_rateints.fits',).
# 2025-04-29 19:13:59,501 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/
#   output_ext: .fits
#   output_use_model: True
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: assign_wcs
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: flat_field
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: photom
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       inverse: False
#       source_type: None
#       mrs_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: ivm
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
# 2025-04-29 19:13:59,676 - stpipe.EurekaImage2Pipeline - INFO - Prefetching reference files for dataset: 'jw01177011001_03101_00001-seg002_mirimage_rateints.fits' reftypes = ['camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2025-04-29 19:13:59,677 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2025-04-29 19:13:59,678 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2025-04-29 19:13:59,678 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2025-04-29 19:13:59,678 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2025-04-29 19:13:59,678 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2025-04-29 19:13:59,679 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2025-04-29 19:13:59,679 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2025-04-29 19:13:59,679 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_flat_0828.fits'.
# 2025-04-29 19:13:59,680 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2025-04-29 19:13:59,680 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2025-04-29 19:13:59,680 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2025-04-29 19:13:59,680 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2025-04-29 19:13:59,680 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2025-04-29 19:13:59,680 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2025-04-29 19:13:59,681 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2025-04-29 19:13:59,681 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2025-04-29 19:13:59,681 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2025-04-29 19:13:59,681 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2025-04-29 19:13:59,682 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2025-04-29 19:13:59,682 - stpipe.EurekaImage2Pipeline - INFO - Starting calwebb_image2 ...
# 2025-04-29 19:13:59,682 - stpipe.EurekaImage2Pipeline - INFO - Processing product ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg002_mirimage
# 2025-04-29 19:13:59,682 - stpipe.EurekaImage2Pipeline - INFO - Working on input ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg002_mirimage_rateints.fits ...
# 2025-04-29 19:13:59,914 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg002_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:00,005 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2025-04-29 19:14:00,073 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  346.619818039 -5.069619139 346.649683740 -5.059965021 346.639989701 -5.030072760 346.609986527 -5.039467155
# 2025-04-29 19:14:00,074 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  346.619818039 -5.069619139 346.649683740 -5.059965021 346.639989701 -5.030072760 346.609986527 -5.039467155
# 2025-04-29 19:14:00,074 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2025-04-29 19:14:00,093 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2025-04-29 19:14:00,182 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg002_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:00,214 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Using FLAT reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_flat_0828.fits
# 2025-04-29 19:14:00,214 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2025-04-29 19:14:00,214 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2025-04-29 19:14:00,215 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2025-04-29 19:14:00,580 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Step flat_field done
# 2025-04-29 19:14:00,661 - stpipe.EurekaImage2Pipeline.photom - INFO - Step photom running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg002_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:00,661 - stpipe.EurekaImage2Pipeline.photom - INFO - Step skipped.
# 2025-04-29 19:14:00,662 - stpipe.EurekaImage2Pipeline - INFO - Finished processing product ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg002_mirimage
# 2025-04-29 19:14:00,662 - stpipe.EurekaImage2Pipeline - INFO - ... ending calwebb_image2
# 2025-04-29 19:14:00,663 - stpipe.EurekaImage2Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-04-29 19:14:00,919 - stpipe.EurekaImage2Pipeline - INFO - Saved model in ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg002_mirimage_calints.fits
# 2025-04-29 19:14:00,920 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline done
# 2025-04-29 19:14:00,920 - stpipe - INFO - Results used jwst version: 1.18.0
# Starting file 3 of 10
# Running the Image2Pipeline
# 2025-04-29 19:14:00,944 - stpipe - WARNING - /Users/hdiamondlowe/Functional/Science/Projects/JWebbinars/jwebbinar_prep/jwebbinar41/Eureka/src/eureka/S2_calibrations/s2_calibrate.py:349: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended. See https://jwst-pipeline.readthedocs.io/en/latest/jwst/user_documentation/running_pipeline_python.html#advanced-use-pipeline-run-vs-pipeline-call for more details.
#   self(filename)
#
# 2025-04-29 19:14:00,944 - stpipe - WARNING - /Users/hdiamondlowe/Programs/miniconda3/envs/eureka/lib/python3.13/site-packages/stpipe/step.py:580: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended.
#   warnings.warn(
#
# 2025-04-29 19:14:01,027 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline running with args ('../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg003_mirimage_rateints.fits',).
# 2025-04-29 19:14:01,031 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/
#   output_ext: .fits
#   output_use_model: True
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: assign_wcs
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: flat_field
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: photom
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       inverse: False
#       source_type: None
#       mrs_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: ivm
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
# 2025-04-29 19:14:01,206 - stpipe.EurekaImage2Pipeline - INFO - Prefetching reference files for dataset: 'jw01177011001_03101_00001-seg003_mirimage_rateints.fits' reftypes = ['camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2025-04-29 19:14:01,208 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2025-04-29 19:14:01,208 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2025-04-29 19:14:01,208 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2025-04-29 19:14:01,208 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2025-04-29 19:14:01,208 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2025-04-29 19:14:01,209 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2025-04-29 19:14:01,209 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2025-04-29 19:14:01,209 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_flat_0828.fits'.
# 2025-04-29 19:14:01,210 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2025-04-29 19:14:01,210 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2025-04-29 19:14:01,210 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2025-04-29 19:14:01,210 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2025-04-29 19:14:01,210 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2025-04-29 19:14:01,211 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2025-04-29 19:14:01,211 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2025-04-29 19:14:01,211 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2025-04-29 19:14:01,211 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2025-04-29 19:14:01,211 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2025-04-29 19:14:01,211 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2025-04-29 19:14:01,212 - stpipe.EurekaImage2Pipeline - INFO - Starting calwebb_image2 ...
# 2025-04-29 19:14:01,212 - stpipe.EurekaImage2Pipeline - INFO - Processing product ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg003_mirimage
# 2025-04-29 19:14:01,212 - stpipe.EurekaImage2Pipeline - INFO - Working on input ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg003_mirimage_rateints.fits ...
# 2025-04-29 19:14:01,445 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg003_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:01,536 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2025-04-29 19:14:01,603 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  346.619818039 -5.069619139 346.649683740 -5.059965021 346.639989701 -5.030072760 346.609986527 -5.039467155
# 2025-04-29 19:14:01,604 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  346.619818039 -5.069619139 346.649683740 -5.059965021 346.639989701 -5.030072760 346.609986527 -5.039467155
# 2025-04-29 19:14:01,604 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2025-04-29 19:14:01,623 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2025-04-29 19:14:01,708 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg003_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:01,740 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Using FLAT reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_flat_0828.fits
# 2025-04-29 19:14:01,741 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2025-04-29 19:14:01,741 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2025-04-29 19:14:01,741 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2025-04-29 19:14:02,101 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Step flat_field done
# 2025-04-29 19:14:02,178 - stpipe.EurekaImage2Pipeline.photom - INFO - Step photom running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg003_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:02,178 - stpipe.EurekaImage2Pipeline.photom - INFO - Step skipped.
# 2025-04-29 19:14:02,179 - stpipe.EurekaImage2Pipeline - INFO - Finished processing product ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg003_mirimage
# 2025-04-29 19:14:02,179 - stpipe.EurekaImage2Pipeline - INFO - ... ending calwebb_image2
# 2025-04-29 19:14:02,180 - stpipe.EurekaImage2Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-04-29 19:14:02,438 - stpipe.EurekaImage2Pipeline - INFO - Saved model in ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg003_mirimage_calints.fits
# 2025-04-29 19:14:02,439 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline done
# 2025-04-29 19:14:02,439 - stpipe - INFO - Results used jwst version: 1.18.0
# Starting file 4 of 10
# Running the Image2Pipeline
# 2025-04-29 19:14:02,466 - stpipe - WARNING - /Users/hdiamondlowe/Functional/Science/Projects/JWebbinars/jwebbinar_prep/jwebbinar41/Eureka/src/eureka/S2_calibrations/s2_calibrate.py:349: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended. See https://jwst-pipeline.readthedocs.io/en/latest/jwst/user_documentation/running_pipeline_python.html#advanced-use-pipeline-run-vs-pipeline-call for more details.
#   self(filename)
#
# 2025-04-29 19:14:02,467 - stpipe - WARNING - /Users/hdiamondlowe/Programs/miniconda3/envs/eureka/lib/python3.13/site-packages/stpipe/step.py:580: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended.
#   warnings.warn(
#
# 2025-04-29 19:14:02,548 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline running with args ('../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg004_mirimage_rateints.fits',).
# 2025-04-29 19:14:02,552 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/
#   output_ext: .fits
#   output_use_model: True
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: assign_wcs
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: flat_field
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: photom
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       inverse: False
#       source_type: None
#       mrs_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: ivm
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
# 2025-04-29 19:14:02,730 - stpipe.EurekaImage2Pipeline - INFO - Prefetching reference files for dataset: 'jw01177011001_03101_00001-seg004_mirimage_rateints.fits' reftypes = ['camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2025-04-29 19:14:02,731 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2025-04-29 19:14:02,732 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2025-04-29 19:14:02,732 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2025-04-29 19:14:02,732 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2025-04-29 19:14:02,732 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2025-04-29 19:14:02,732 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2025-04-29 19:14:02,733 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2025-04-29 19:14:02,733 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_flat_0828.fits'.
# 2025-04-29 19:14:02,733 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2025-04-29 19:14:02,734 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2025-04-29 19:14:02,734 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2025-04-29 19:14:02,734 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2025-04-29 19:14:02,734 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2025-04-29 19:14:02,734 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2025-04-29 19:14:02,735 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2025-04-29 19:14:02,735 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2025-04-29 19:14:02,735 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2025-04-29 19:14:02,735 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2025-04-29 19:14:02,735 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2025-04-29 19:14:02,736 - stpipe.EurekaImage2Pipeline - INFO - Starting calwebb_image2 ...
# 2025-04-29 19:14:02,736 - stpipe.EurekaImage2Pipeline - INFO - Processing product ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg004_mirimage
# 2025-04-29 19:14:02,736 - stpipe.EurekaImage2Pipeline - INFO - Working on input ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg004_mirimage_rateints.fits ...
# 2025-04-29 19:14:02,968 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg004_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:03,058 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2025-04-29 19:14:03,126 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  346.619818039 -5.069619139 346.649683740 -5.059965021 346.639989701 -5.030072760 346.609986527 -5.039467155
# 2025-04-29 19:14:03,127 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  346.619818039 -5.069619139 346.649683740 -5.059965021 346.639989701 -5.030072760 346.609986527 -5.039467155
# 2025-04-29 19:14:03,127 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2025-04-29 19:14:03,146 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2025-04-29 19:14:03,230 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg004_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:03,261 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Using FLAT reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_flat_0828.fits
# 2025-04-29 19:14:03,262 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2025-04-29 19:14:03,262 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2025-04-29 19:14:03,262 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2025-04-29 19:14:03,626 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Step flat_field done
# 2025-04-29 19:14:03,715 - stpipe.EurekaImage2Pipeline.photom - INFO - Step photom running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg004_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:03,716 - stpipe.EurekaImage2Pipeline.photom - INFO - Step skipped.
# 2025-04-29 19:14:03,716 - stpipe.EurekaImage2Pipeline - INFO - Finished processing product ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg004_mirimage
# 2025-04-29 19:14:03,717 - stpipe.EurekaImage2Pipeline - INFO - ... ending calwebb_image2
# 2025-04-29 19:14:03,717 - stpipe.EurekaImage2Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-04-29 19:14:03,976 - stpipe.EurekaImage2Pipeline - INFO - Saved model in ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg004_mirimage_calints.fits
# 2025-04-29 19:14:03,977 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline done
# 2025-04-29 19:14:03,977 - stpipe - INFO - Results used jwst version: 1.18.0
# Starting file 5 of 10
# Running the Image2Pipeline
# 2025-04-29 19:14:04,001 - stpipe - WARNING - /Users/hdiamondlowe/Functional/Science/Projects/JWebbinars/jwebbinar_prep/jwebbinar41/Eureka/src/eureka/S2_calibrations/s2_calibrate.py:349: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended. See https://jwst-pipeline.readthedocs.io/en/latest/jwst/user_documentation/running_pipeline_python.html#advanced-use-pipeline-run-vs-pipeline-call for more details.
#   self(filename)
#
# 2025-04-29 19:14:04,001 - stpipe - WARNING - /Users/hdiamondlowe/Programs/miniconda3/envs/eureka/lib/python3.13/site-packages/stpipe/step.py:580: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended.
#   warnings.warn(
#
# 2025-04-29 19:14:04,073 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline running with args ('../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg005_mirimage_rateints.fits',).
# 2025-04-29 19:14:04,077 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/
#   output_ext: .fits
#   output_use_model: True
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: assign_wcs
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: flat_field
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: photom
#       search_output_file: True
# ...
# 2025-04-29 19:14:10,399 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2025-04-29 19:14:10,400 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2025-04-29 19:14:10,400 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2025-04-29 19:14:10,400 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2025-04-29 19:14:10,400 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2025-04-29 19:14:10,400 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2025-04-29 19:14:10,400 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2025-04-29 19:14:10,401 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2025-04-29 19:14:10,401 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2025-04-29 19:14:10,401 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2025-04-29 19:14:10,401 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2025-04-29 19:14:10,402 - stpipe.EurekaImage2Pipeline - INFO - Starting calwebb_image2 ...
# 2025-04-29 19:14:10,402 - stpipe.EurekaImage2Pipeline - INFO - Processing product ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg009_mirimage
# 2025-04-29 19:14:10,402 - stpipe.EurekaImage2Pipeline - INFO - Working on input ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg009_mirimage_rateints.fits ...
# 2025-04-29 19:14:10,628 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg009_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:10,720 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2025-04-29 19:14:10,791 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  346.619818039 -5.069619139 346.649683740 -5.059965021 346.639989701 -5.030072760 346.609986527 -5.039467155
# 2025-04-29 19:14:10,791 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  346.619818039 -5.069619139 346.649683740 -5.059965021 346.639989701 -5.030072760 346.609986527 -5.039467155
# 2025-04-29 19:14:10,792 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2025-04-29 19:14:10,810 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2025-04-29 19:14:10,901 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg009_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:10,935 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Using FLAT reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_flat_0828.fits
# 2025-04-29 19:14:10,935 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2025-04-29 19:14:10,935 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2025-04-29 19:14:10,936 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2025-04-29 19:14:11,301 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Step flat_field done
# 2025-04-29 19:14:11,387 - stpipe.EurekaImage2Pipeline.photom - INFO - Step photom running with args (<CubeModel(40, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg009_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:11,388 - stpipe.EurekaImage2Pipeline.photom - INFO - Step skipped.
# 2025-04-29 19:14:11,388 - stpipe.EurekaImage2Pipeline - INFO - Finished processing product ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg009_mirimage
# 2025-04-29 19:14:11,389 - stpipe.EurekaImage2Pipeline - INFO - ... ending calwebb_image2
# 2025-04-29 19:14:11,389 - stpipe.EurekaImage2Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-04-29 19:14:11,654 - stpipe.EurekaImage2Pipeline - INFO - Saved model in ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg009_mirimage_calints.fits
# 2025-04-29 19:14:11,654 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline done
# 2025-04-29 19:14:11,655 - stpipe - INFO - Results used jwst version: 1.18.0
# Starting file 10 of 10
# Running the Image2Pipeline
# 2025-04-29 19:14:11,678 - stpipe - WARNING - /Users/hdiamondlowe/Functional/Science/Projects/JWebbinars/jwebbinar_prep/jwebbinar41/Eureka/src/eureka/S2_calibrations/s2_calibrate.py:349: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended. See https://jwst-pipeline.readthedocs.io/en/latest/jwst/user_documentation/running_pipeline_python.html#advanced-use-pipeline-run-vs-pipeline-call for more details.
#   self(filename)
#
# 2025-04-29 19:14:11,679 - stpipe - WARNING - /Users/hdiamondlowe/Programs/miniconda3/envs/eureka/lib/python3.13/site-packages/stpipe/step.py:580: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended.
#   warnings.warn(
#
# 2025-04-29 19:14:11,759 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline running with args ('../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg010_mirimage_rateints.fits',).
# 2025-04-29 19:14:11,763 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/
#   output_ext: .fits
#   output_use_model: True
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: assign_wcs
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: flat_field
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: photom
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       inverse: False
#       source_type: None
#       mrs_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: ivm
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
# 2025-04-29 19:14:11,853 - stpipe.EurekaImage2Pipeline - INFO - Prefetching reference files for dataset: 'jw01177011001_03101_00001-seg010_mirimage_rateints.fits' reftypes = ['camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2025-04-29 19:14:11,855 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2025-04-29 19:14:11,855 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2025-04-29 19:14:11,856 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2025-04-29 19:14:11,856 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2025-04-29 19:14:11,856 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2025-04-29 19:14:11,856 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2025-04-29 19:14:11,857 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2025-04-29 19:14:11,857 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_flat_0828.fits'.
# 2025-04-29 19:14:11,857 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2025-04-29 19:14:11,857 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2025-04-29 19:14:11,858 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2025-04-29 19:14:11,858 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2025-04-29 19:14:11,858 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2025-04-29 19:14:11,858 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2025-04-29 19:14:11,858 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2025-04-29 19:14:11,858 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2025-04-29 19:14:11,859 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2025-04-29 19:14:11,859 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2025-04-29 19:14:11,859 - stpipe.EurekaImage2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2025-04-29 19:14:11,859 - stpipe.EurekaImage2Pipeline - INFO - Starting calwebb_image2 ...
# 2025-04-29 19:14:11,860 - stpipe.EurekaImage2Pipeline - INFO - Processing product ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg010_mirimage
# 2025-04-29 19:14:11,860 - stpipe.EurekaImage2Pipeline - INFO - Working on input ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg010_mirimage_rateints.fits ...
# 2025-04-29 19:14:12,026 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(17, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg010_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:12,124 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2025-04-29 19:14:12,172 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  346.619818039 -5.069619139 346.649683740 -5.059965021 346.639989701 -5.030072760 346.609986527 -5.039467155
# 2025-04-29 19:14:12,173 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  346.619818039 -5.069619139 346.649683740 -5.059965021 346.639989701 -5.030072760 346.609986527 -5.039467155
# 2025-04-29 19:14:12,173 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2025-04-29 19:14:12,193 - stpipe.EurekaImage2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2025-04-29 19:14:12,279 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(17, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg010_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:12,311 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Using FLAT reference file: /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_flat_0828.fits
# 2025-04-29 19:14:12,311 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2025-04-29 19:14:12,312 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2025-04-29 19:14:12,312 - stpipe.EurekaImage2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2025-04-29 19:14:12,502 - stpipe.EurekaImage2Pipeline.flat_field - INFO - Step flat_field done
# 2025-04-29 19:14:12,587 - stpipe.EurekaImage2Pipeline.photom - INFO - Step photom running with args (<CubeModel(17, 1024, 1032) from ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg010_mirimage_eurekaimage2pipeline.fits>,).
# 2025-04-29 19:14:12,587 - stpipe.EurekaImage2Pipeline.photom - INFO - Step skipped.
# 2025-04-29 19:14:12,588 - stpipe.EurekaImage2Pipeline - INFO - Finished processing product ../miri_photometry/Stage1/S1_2025-04-29_miri_photometry_run2/jw01177011001_03101_00001-seg010_mirimage
# 2025-04-29 19:14:12,588 - stpipe.EurekaImage2Pipeline - INFO - ... ending calwebb_image2
# 2025-04-29 19:14:12,588 - stpipe.EurekaImage2Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-04-29 19:14:12,731 - stpipe.EurekaImage2Pipeline - INFO - Saved model in ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/jw01177011001_03101_00001-seg010_mirimage_calints.fits
# 2025-04-29 19:14:12,731 - stpipe.EurekaImage2Pipeline - INFO - Step EurekaImage2Pipeline done
# 2025-04-29 19:14:12,731 - stpipe - INFO - Results used jwst version: 1.18.0
# Saving Metadata
#
# Total time (min): 0.31

# %% [markdown]
# ---
# # Stage 3: Eureka!

# %% [markdown]
# ### Setting the Stage 3 "Eureka! Control File" (ECF)
#
# **This determines what will happen during Stage 3**
#
# To begin, please first copy below the contents of the ECF template for MIRI/LRS from the `S3_miri_lrs_template.ecf` file in the ECF demos folder on [GitHub](https://github.com/kevin218/Eureka/tree/main/demos/JWST).
#
# The most important parameters and their recommended settings are described below, but more context can be found on the [Eureka! documentation website](https://eurekadocs.readthedocs.io/en/latest/ecf.html#stage-3).
#
# 1.   Set `ncpu` to the number of CPU threads you want to use. If set to `1` no multiprocessing will be done, and this parameter can be increased to ~2x your CPU core count for faster runs.
# 2.   Set both `ywindow` and `xwindow` to `None` - this will crop a 150x150 pixel box around the approximate centroid (since the MIRI full frame images are very large and it is generally helpful and faster to zoom-in on the science target).
# 3.   Set `dqmask` to `True` to mask known-bad pixels.
#
# 4.   Set `ff_outlier` to `True`. If set to `True`, this step would perform sigma clipping along the entire time axis for the entire frame, while this is only done to the background pixels if `ff_outlier` is set to `False`. Setting `ff_outlier` to `True` is only really safe for observations of shallow eclipses where the sigma-clipping algorithm is unlikely to confuse an astrophysical signal as being an outlier.
# 5.   Set `bg_thresh` (background area outlier threshold) values to `[5,5]` to do two iterations of 5-sigma clipping along the time axis to remove artifacts like cosmic rays.
# 6.   Set `interp_method` to `linear`. This controls how bad pixels are replaced through interpolation, with options `None` (if no interpolation should be performed), `linear`, `nearest`, and `cubic`.
#
# 7.   Set `centroid_method` to `mgmc` - this controls the photometric centroiding algoirthm, with options of `fgc` or `mgmc`.
# 8.   Set `ctr_guess` to `fits` to use the approximate centroid position from the FITS header as the starting guess for the centroiding algorithm.
# 9.   Set `ctr_cutout_size` to `10`. This is used to make a temporary smaller subarray centered on the initial centroid position guess in order to produce a better centroid position that is less biased by background levels and/or nearby stars.
# 10.   Set `centroid_tech` to `com` to use the center-of-mass option which generally provides precise and stable centroid positions for TSO photometry. Other options are `1dg` and `2dg` which fit 1D or 2D Gaussians to the images to estimate the centroid.
#
# 11.   Set `phot_method` to `photutils` to use the photutils aperture photometric extraction algorithm. Other options include `poet` (aperture photometry using code from POET), or `optimal` (for optimal photometric extraction)
# 12.   Set `aperture_edge` to `exact` to weight each pixel by the fractional area that lies within the aperture. The other option is `center` which only includes pixels if their center lies within the aperture.
# 13.   Set `aperture_shape` to `circle` to use a circular photometric aperture. If `phot_method` is `photutils` or `optimal`, the options are `circle`, `ellipse`, or `rectangle`. If `phot_utils` is `poet`, the options are `circle` or `hexagon`. This parameter is used to set both the object aperture shape and the sky annulus shape
# 14.   Set `moving_centroid` to `False` to keep the aperture fixed on the median centroid location. If set to `True`, the aperture would track the moving centroid.
# 15.   Set `skip_apphot_bg` to `False` to perform background subtraction using a background annulus. If set to `False`, skips the background subtraction during the aperture photometry step.
# 16.   Set `photap` to `5` to set the size of photometry aperture radius in pixels.
# 17.   Set `skyin` to `16` to set the radius of the inner sky annulus edge, in pixels.
# 18.   Set `skywidth` to `32` to set the width of the sky annulus, in pixels.
#
# 19.  Set `isplots_S3` to `4` to get lots of useful diagnostic figures (increase this to 5 if you need more plots to investigate problems).
# 20.  Set `nplots` to `5` to make repetitive figures only for the first 5 integrations (you can increase this as needed if you want more figures for troubleshooting)
# 21.  Set `hide_plots` to `False` so that the figures pop up in this notebook as they're made (set to `True` if you're not running the code in a notebook, otherwise you'll have a lot of windows popping up).
# 22.  Set `verbose` to `True` so you get lots of useful information printed out.
# 23.  Set `topdir` to the same value as you used in Stage 2

# %%
s3_ecf_contents = f"""
# Eureka! Control File for Stage 3: Data Reduction

# Stage 3 Documentation: https://eurekadocs.readthedocs.io/en/latest/ecf.html#stage-3

ncpu            16
nfiles          200
max_memory      1.5
indep_batches   False       # Independently treat each batch of files? Strongly recommended to leave this as False unless you have a clear reason to set it to True.
suffix          calints

calibrated_spectra  False   # Set True to generate flux-calibrated spectra/photometry in mJy
                            # Set False to convert to electrons
pmap            1364

# Subarray region of interest
ywindow         None        # Vertical axis as seen in DS9
xwindow         None        # Horizontal axis as seen in DS9
dqmask          True

# Background parameters
ff_outlier      True        # Set False to use only background region (recommended for deep transits)
                            # Set True to use full frame (works well for shallow transits/eclipses)
bg_thresh       [5,5]
interp_method   linear      # Interpolate bad pixels. Options: None (if no interpolation should be performed), linear, nearest, cubic

# Centroiding parameters
centroid_method mgmc        # Method used for centroiding. Options: mgmc, fgc
ctr_guess       fits        # Initial guess of centroid position. If None, will first perform centroiding on whole frame (can sometimes fail)
ctr_cutout_size 10          # Cutoff size all around the centroid after the coarse centroid calculation or first centroid guess when using the mgmc method.
centroid_tech   com         # (mgmc method param) Technique used for centroiding. Options: com, 1dg, 2dg
gauss_frame     15          # (mgmc method param) Half-width away from second centroid guess to include in centroiding map for gaussian widths. Recommend ~15 for MIRI photometry.

# Photometric extraction parameters
phot_method     photutils   # photutils (aperture photometry using photutils), poet (aperture photometry using code from POET), or optimal (for optimal photometric extraction)
aperture_edge   exact       # center (pixel is included only if its center lies within the aperture), or exact (pixel is weighted by the fractional area that lies within the aperture)
aperture_shape  circle      # If phot_method is photutils or optimal: circle, ellipse, or rectangle. If phot_utils is poet: circle or hexagon. Used to set both the object aperture shape and the sky annulus shape
moving_centroid False       # Boolean: False if the aperture should stay fixed on the median centroid location (recommended), or True if the aperture should track the moving centroid
skip_apphot_bg  False       # Skips the background subtraction during the aperture photometry step
photap          5           # Size of photometry aperture radius in pixels
skyin           16          # Inner sky annulus edge, in pixels
skywidth        32          # Width of the sky annulus, in pixels

# Diagnostics
isplots_S3      4           # Generate few (1), some (3), or many (5) figures (Options: 1 - 5)
nplots          1           # How many of each type of figure do you want to make per file?
hide_plots      False       # If True, plots will automatically be closed rather than popping up
save_output     True        # Save outputs for use in S4
save_fluxdata   False       # Save FluxData outputs for debugging or use with other tools (can be quite large files)
verbose         True        # If True, more details will be printed about steps

# Project directory
topdir          ../miri_photometry/

# Directories relative to project dir
inputdir        Stage2
outputdir       Stage3
"""

# This will save the ECF as a file that the next cell can read-in
with open(f'./S3_{eventlabel}.ecf', 'w') as f:
    f.write(s3_ecf_contents)

# %% [markdown]
# ### Running Eureka!'s Stage 3
#
# The following cell will run Eureka!'s Stage 3 using the settings you defined above. Note that your ECF will be copied to your output folder, making it easy to remember how you produced those outputs hours, days, or years after you reduced the data.
#
# This stage of Eureka! will take ~1 minute for these particular data.

# %%
s3_spec, s3_meta = eureka.S3_data_reduction.s3_reduce.reduce(eventlabel, ecf_path='./')
# Out:
# Starting Stage 3 Reduction
#
# Input directory: ../miri_photometry/Stage2/S2_2025-04-29_miri_photometry_run1/
#   Found 10 data file(s) ending in calints.fits
# Output directory: ../miri_photometry/Stage3/S3_2025-04-29_miri_photometry_run1/ap5_bg16_48/
# Using ap=5, bg=16_48, expand=1
# Copying S3 control file
# Starting batch 1 of 1 with 10 files
#   Reading file 10...
#   Concatenating files...
#   Masking NaNs/infs in data arrays...
#     FLUX has 35464 NaNs/infs, which is 0.41% of all pixels.
#     ERR has 35464 NaNs/infs, which is 0.41% of all pixels.
#     V0 has 35464 NaNs/infs, which is 0.41% of all pixels.
#   Converting from data numbers per second (DN/s) to electrons...
#   Automatically getting reference files...
# 2025-04-29 19:19:15,263 - CRDS - INFO -  Fetching  /Users/hdiamondlowe/Programs/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits    4.2 M bytes  (1 / 1 files) (0 / 4.2 M bytes)
#   Performing full frame outlier rejection...
#     Flagged 0.006980% of pixels as bad.
#   Computing clean median frame...
#   Using approximate centroid position from FITS header for initial centroid estimate
#   Interpolating masked values: 100%|██████████████████████████████████| 377/377 [00:10<00:00, 37.28it/s]
#   Doing second round of mgmc centroiding...
#   Doing photometric extraction...
# Stage 3 MAD = 834 ppm
# Finished writing to ../miri_photometry/Stage3/S3_2025-04-29_miri_photometry_run1/ap5_bg16_48/S3_miri_photometry_ap5_bg16_48_SpecData.h5
#
# Total time (min): 1.01

# %% [markdown]
# ---
# # Stage 4: Eureka!

# %% [markdown]
# ## Broadband lightcurve

# %% [markdown]
# ### Setting the Stage 4 "Eureka! Control File" (ECF)
#
# This determines what will happen during Stage 4
#
# To begin, please first copy below the contents of the ECF template for MIRI/LRS from the `S4_template.ecf` file in the ECF demos folder on [GitHub](https://github.com/kevin218/Eureka/tree/main/demos/JWST).
#
# The most important parameters and their recommended settings are described below, but more context can be found on the [Eureka! documentation website](https://eurekadocs.readthedocs.io/en/latest/ecf.html#stage-4).
#
#
# To sigma-clip outliers, we need to have a reference time-series against which we are comparing our observations. If we just took the whole time-series and sigma clipped compared to the median level of the observations, we may well sigma-clip the entire transit signal in cases where there is a strong transit. Instead, we use a [box-car](https://en.wikipedia.org/wiki/Boxcar_function) filter which acts as a [high-pass filter](https://en.wikipedia.org/wiki/High-pass_filter); this removes any low-frequency signals (e.g. transit ingress/egress, phase variations, linear trends in time) and leaves behind high-frequency noise (cosmic rays, HGA moves, etc.). The most important parameters that control this box-car clipping are `sigma` and `box_width`, but `boundary` and `fill_value` are also relevant parameters.
#
# 1.   Remove outliers along the time axis (e.g. cosmic rays) by setting `clip_binned` to `True` (basically always helpful). `clip_unbinned` is typically not helpful and should be set to `False`.
# 2.   Set `sigma` to a value low enough to clip any obviously errant points while ensuring you are not clipping an excessive number of points and not clipping the transit or eclipse's ingress/egress. For these particular data, something around `3.5` should do, but this is not a strict rule and will change for each different dataset. The focus here is to remove obviously errant points and not to clip a bunch of points.
# 3.   Set `box_width` to a value small enough to not sigma-clip the transit or eclipse's ingress/egress, while also not setting it so small that the smoothed copy of the signal is excessively noisy. For these particular data, something around `20` should do, but again this is not a strict rule and will change for each different dataset.
# 4.   Set `boundary` to `fill` as this typically results in reasonable behaviour at the start and end of the observations.
# 5.   Set `fill_value` to `mask` in order to mask the clipped outliers without replacement. This ensures you remove bad values without requiring you to replace the masked values with a guess as to the value the point should have (a potentially dangerous endeavour).
#
#
# Finally, there are some plotting/logging controls you should adjust:
#
# 6.  Set `compute_ld` to `False`. Since we're working on an eclipse observation, there is no need to compute theoretical limb-darkening coefficients for the star. The other inputs related to computing limb-darkening coefficients can then safely be ignored.
# 7.  Set `isplots_S4` to `3` to get some useful diagnostic figures (increase this to 5 if you need more plots to investigate problems).
# 8.  Set `hide_plots` to `False` so that the figures pop up in this notebook as they're made (set to `True` if you're running the code in the terminal instead of a notebook, otherwise you'll have a lot of windows popping up).
# 9.  Set `verbose` to `True` so you get lots of useful information printed out.
# 10.  Set `topdir` to the same value as you used in Stage 3.
# 11.  Set `inputdir` to `Stage3`. If you end up running multiple version of Eureka!'s Stage 3, you can select the exact one you want as an input to Stage 4 by specifying the folder name in more detail (e.g. `Stage3/S3_2023-07-24_miri_run1`).
# 12.  Set `outputdir` to `Stage4`

# %%
s4_ecf_contents = f"""
# Eureka! Control File for Stage 4: Generate Lightcurves

# Stage 4 Documentation: https://eurekadocs.readthedocs.io/en/latest/ecf.html#stage-4

allapers        True    # Run S4 on all of the apertures considered in S3 Otherwise will use newest output in the inputdir

# Number of spectroscopic channels spread evenly over given wavelength range
nspecchan       1           # Number of spectroscopic channels spread evenly over given wavelength range. Set to None to leave the spectrum unbinned.
compute_white   False       # Also compute the white-light lightcurve

# Parameters for sigma clipping
clip_binned     True    # Whether or not sigma clipping should be performed on the binned 1D time series
sigma           3.5     # The number of sigmas a point must be from the rolling median to be considered an outlier
box_width       20      # The width of the box-car filter (used to calculated the rolling median) in units of number of data points
maxiters        20      # The number of iterations of sigma clipping that should be performed.
boundary        fill    # Use 'fill' to extend the boundary values by the median of all data points (recommended), 'wrap' to use a periodic boundary, or 'extend' to use the first/last data points
fill_value      mask    # Either the string 'mask' to mask the outlier values (recommended), 'boxcar' to replace data with the mean from the box-car filter, or a constant float-type fill value.

# Limb-darkening parameters needed to compute exotic-ld
compute_ld      False

# Diagnostics
isplots_S4      3       # Generate few (1), some (3), or many (5) figures (Options: 1 - 5)
hide_plots      False   # If True, plots will automatically be closed rather than popping up
verbose         True    # If True, more details will be printed about steps

# Project directory
topdir          ../miri_photometry/

# Directories relative to project dir
inputdir        Stage3
outputdir       Stage4
"""

# This will save the ECF as a file that the next cell can read-in
with open(f'S4_{eventlabel}.ecf', 'w') as f:
    f.write(s4_ecf_contents)

# %% [markdown]
# ### Running Eureka!'s Stage 4
#
# The following cell will run Eureka!'s Stage 4 using the settings you defined above. Note that your ECF will be copied to your output folder, making it easy to remember how you produced those outputs hours, days, or years after you reduced the data.
#
# This stage of Eureka! will take &lt;&lt;1 minute to complete for these particular data.

# %%
s4_spec, s4_lc, s4_meta = eureka.S4_generate_lightcurves.s4_genLC.genlc(eventlabel, ecf_path='./')
# Out:
# Finished loading parameters from ../miri_photometry/Stage3/S3_2025-04-29_miri_photometry_run1/ap5_bg16_48/S3_miri_photometry_ap5_bg16_48_SpecData.h5
# Finished loading parameters from ../miri_photometry/Stage3/S3_2025-04-29_miri_photometry_run1/ap5_bg16_48/S3_miri_photometry_ap5_bg16_48_SpecData.h5
#
# Starting Stage 4: Generate Light Curves
#
# Input directory: ../miri_photometry/Stage3/S3_2025-04-29_miri_photometry_run1/ap5_bg16_48/
# Output directory: ../miri_photometry/Stage4/S4_2025-04-29_miri_photometry_run1/ap5_bg16_48/
# Copying S4 control file
# Loading S3 save file:
# ../miri_photometry/Stage3/S3_2025-04-29_miri_photometry_run1/ap5_bg16_48/S3_miri_photometry_ap5_bg16_48_SpecData.h5
# Finished loading parameters from ../miri_photometry/Stage3/S3_2025-04-29_miri_photometry_run1/ap5_bg16_48/S3_miri_photometry_ap5_bg16_48_SpecData.h5
# No value was provided for meta.wave_min, so defaulting to 15.0.
# No value was provided for meta.wave_max, so defaulting to 15.0.
# Stage 4 MAD = 833.96 ppm
# Generating light curves
#   Sigma clipped 9 outliers in time series
#     MAD = 804 ppm
# Saving results...
# Finished writing to ../miri_photometry/Stage4/S4_2025-04-29_miri_photometry_run1/ap5_bg16_48/S4_miri_photometry_ap5_bg16_48_SpecData.h5
# Finished writing to ../miri_photometry/Stage4/S4_2025-04-29_miri_photometry_run1/ap5_bg16_48/S4_miri_photometry_ap5_bg16_48_LCData.h5
#
# Total time (min): 0.02

# %% [markdown]
# ---
# # Bonus: Getting the "best" reduction
#
# Seeking the "best" reduction is where we venture into the art of data reduction, with various parameters sometimes having appreciable impacts on the precision we can get from our observations and (frighteningly) sometimes significantly impacting our final planetary spectra. At all times, think critically about the settings you are using and the potential for unintended consequences.
#
# If you want to try to get even better results, focus on trying different values in Stage 3 for:
#
# **Most impactful:**
# *   `photap` (with a larger aperture you capture more of the star's light but also capture more noisy background light - there is a trade-off here which will likely change for every different target you observe)
# *   `skyin` (with a smaller skyin you probe closer to the star but also more stellar contamination - there is a trade-off here which will likely change for every different target you observe)
# *   `skywidth` (with a larger skywidth you average over more background pixels but you also probe less close to the star - there is a trade-off here which will likely change for every different target you observe)
#
# **Uncertain impact:**
# *   `bg_thresh` (you likely won't see large changes, but might slightly improve the overall scatter)
# *   `interp_method` (similarly, you likely won't see large changes, but might slightly improve the overall scatter)
# *   `aperture_edge` (the best value will likely normally be `'exact'`, but that may not always be the case)
# *   `aperture_shape` (the best value will likely normally be `'circle'`, but that may not always be the case)
#
# <br/>
#
# Typically the "best" value for each parameter is independent of the values of other parameters, but sometimes there are interactions (e.g., in spectroscopic datasets a smaller `bg_hw` may require smaller `p3thresh`). The Stage 4 MAD (Median Absolute Deviation) value is an approximate tool you can use to determine how much your reduction has improved (typically the lower the value, the lower the noise in your lightcurve, and the "better" the reduction). A better indication of an improved reduction is the RMS of the residuals from your Stage 5 fit since the Stage 4 MAD doesn't account for noise that can be decorrelated when fitting, but depending on your dataset it can be prohibitively time-intensive to continuously run all reduction options through Stage 5.
#
# Again though, remain critical and vigilant at all times when optimizing your reduction. For example, you'll be able to decrease your MAD value by setting your Stage 4 `sigma` value to `0.01`, but you're going to end up discarding nearly all of your data which you definitely don't want to do. A less obvious danger might be setting Stage 3's `bg_hw` parameter to too small a value, resulting in self-subtraction and potentially biased transit or eclipse depths.
